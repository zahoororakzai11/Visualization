# %% [markdown]
# <a href="https://colab.research.google.com/github/zahoororakzai11/Visualization/blob/main/Visualization_IMportance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('/content/sample_data/tsa_melted_holiday_travel.csv')
data.head()
# Out:
#          date  year  travelers         holiday
# 0  2019-01-01  2019  2126398.0  New Year's Day
# 1  2019-01-02  2019  2345103.0  New Year's Day
# 2  2019-01-03  2019  2202111.0             NaN
# 3  2019-01-04  2019  2150571.0             NaN
# 4  2019-01-05  2019  1975947.0             NaN

# %%
import seaborn as sns
sns.displot(data = data, x = 'travelers',col='year',kde = True,height = 2.5)
